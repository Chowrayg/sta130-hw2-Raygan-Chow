# %% [markdown]
# For our group, my biggest flaw was the lack of technical support. The other three members contributed one research topic each while I tried to string their arguments into clear motives. This led to good feedback from different groups during yesterday's showing. Still, it also meant I could not contribute much during Q&A: the only parts I did were non-technical and therefore "unworthy" of questions, and I wasn't prepared to answer questions for my groupmates. Overall, I believe we did objectively reasonably as we explained our tests, visualizations, etc. clearly enough without making the audience lose track of our motive - to provide general directions for three potential rapid evidence briefs on high school students.

# %% [markdown]
# For group 27, I liked their testing methods and their variance. Both the Chi-Square Test and Regression decision tree were used appropriately. The latter is well explained during the elevator pitch, but the decision tree on the slide is too clunked for further examination. I believe this is also their biggest flaw: having every relevant info for a topic on the same slide is well-intentioned, but when you put both the visualization and test description on the same slide, it is impossible to read. It's more of a presentation problem than a technical problem, though, and they did well overall.

# %% [markdown]
# For group 3, they had a clear focus on data storytelling. They used a combination of descriptive statistics and scatter plots to illustrate trends, which made their conclusions easy to follow. However, their analysis lacked depth; while the visuals were compelling, they did not fully explain the statistical tests or justify their choice of methods. This led to a problematic Q&A as most questions were answered vaguely, but in fairness, if I were faced with technical questions, I would've also been a blank sheet as I was ignorant of my groupmates' details. Despite this, their ability to engage the audience and keep the discussion centered on the broader implications of their findings was commendable.
